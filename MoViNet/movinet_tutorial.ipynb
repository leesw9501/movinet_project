# %%
# !pip install av
! wget https://raw.githubusercontent.com/pytorch/vision/6de158c473b83cf43344a0651d7c01128c7850e6/references/video_classification/transforms.py
# Download HMDB51 data and splits from serre lab website
! wget http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
! wget http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Out:
# Requirement already satisfied: av in c:\users\user001\anaconda3\envs\tf24_gpu\lib\site-packages (8.0.3)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\user001\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\user001\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\user001\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\user001\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\user001\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\user001\appdata\roaming\python\python38\site-packages)
# --2021-10-26 15:47:18--  https://raw.githubusercontent.com/pytorch/vision/6de158c473b83cf43344a0651d7c01128c7850e6/references/video_classification/transforms.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3102 (3.0K) [text/plain]
# Saving to: 'transforms.py.1'
#
#      0K ...                                                   100%  157K=0.02s
#
# 2021-10-26 15:47:18 (157 KB/s) - 'transforms.py.1' saved [3102/3102]
#
# --2021-10-26 15:47:18--  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Resolving serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)... 128.148.254.114
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... No data received.
# Retrying.
#
# --2021-10-26 15:48:12--  (try: 2)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... No data received.
# Retrying.
#
# --2021-10-26 15:49:06--  (try: 3)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 15:49:55--  (try: 4)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... No data received.
# Retrying.
#
# --2021-10-26 15:50:51--  (try: 5)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 15:51:42--  (try: 6)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 15:52:29--  (try: 7)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 15:53:17--  (try: 8)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 15:54:06--  (try: 9)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... No data received.
# Retrying.
#
# --2021-10-26 15:55:08--  (try:10)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 15:55:59--  (try:11)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... No data received.
# Retrying.
#
# --2021-10-26 15:57:01--  (try:12)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... No data received.
# Retrying.
#
# --2021-10-26 15:58:03--  (try:13)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 15:58:54--  (try:14)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 15:59:46--  (try:15)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 16:00:46--  (try:16)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 16:01:37--  (try:17)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 16:02:28--  (try:18)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 16:03:19--  (try:19)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 16:04:10--  (try:20)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Giving up.
#
# --2021-10-26 16:04:51--  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Resolving serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)... 128.148.254.114
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... No data received.
# Retrying.
#
# --2021-10-26 16:05:44--  (try: 2)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 16:06:27--  (try: 3)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 16:07:10--  (try: 4)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 16:07:55--  (try: 5)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... No data received.
# Retrying.
#
# --2021-10-26 16:08:53--  (try: 6)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 16:09:39--  (try: 7)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 16:10:27--  (try: 8)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 16:11:16--  (try: 9)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 16:12:06--  (try:10)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 16:12:57--  (try:11)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 16:13:48--  (try:12)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 16:14:49--  (try:13)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 16:15:40--  (try:14)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 16:16:31--  (try:15)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 16:17:22--  (try:16)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... No data received.
# Retrying.
#
# --2021-10-26 16:18:24--  (try:17)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 16:19:15--  (try:18)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Retrying.
#
# --2021-10-26 16:20:06--  (try:19)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... No data received.
# Retrying.
#
# --2021-10-26 16:21:08--  (try:20)  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... Read error (Unknown error) in headers.
# Giving up.

# %%
pip install git+https://github.com/Atze00/MoViNet-pytorch.git
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 파일 이름, 디렉터리 이름 또는 볼륨 레이블 구문이 잘못되었습니다.

# %%
# Extract and organize video data..
! mkdir -p video_data test_train_splits
! unrar e test_train_splits.rar test_train_splits
! rm test_train_splits.rar
! unrar e hmdb51_org.rar 
! rm hmdb51_org.rar
! mv *.rar video_data
import os
for files in os.listdir('video_data'):
    foldername = files.split('.')[0]
    os.system("mkdir -p video_data/" + foldername)
    os.system("unrar e video_data/"+ files + " video_data/"+foldername)

! rm video_data/*.rar
# Out:
# 하위 디렉터리 또는 파일 -p이(가) 이미 있습니다.
# 다음 내용 진행 중 오류 발생: -p.
# 하위 디렉터리 또는 파일 video_data이(가) 이미 있습니다.
# 다음 내용 진행 중 오류 발생: video_data.
# 하위 디렉터리 또는 파일 test_train_splits이(가) 이미 있습니다.
# 다음 내용 진행 중 오류 발생: test_train_splits.
# 'unrar'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
# 'rm'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
# 'unrar'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
# 'rm'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
# 'mv'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
# 'rm'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
import time
import torchvision
import torch.nn.functional as F
import torchvision.transforms as transforms
import torch.optim as optim
from torch.utils.data import random_split, DataLoader
import torch
import transforms as T
from movinets import MoViNet
from movinets.config import _C

torch.manual_seed(97)
num_frames = 16 # 16
clip_steps = 2
Bs_Train = 16
Bs_Test = 16

transform = transforms.Compose([  
                                                     
                                 T.ToFloatTensorInZeroOne(),
                                 T.Resize((200, 200)),
                                 T.RandomHorizontalFlip(),
                                 #T.Normalize(mean=[0.43216, 0.394666, 0.37645], std=[0.22803, 0.22145, 0.216989]),
                                 T.RandomCrop((172, 172))])
transform_test = transforms.Compose([                           
                                 T.ToFloatTensorInZeroOne(),
                                 T.Resize((200, 200)),
                                 #T.Normalize(mean=[0.43216, 0.394666, 0.37645], std=[0.22803, 0.22145, 0.216989]),
                                 T.CenterCrop((172, 172))])

hmdb51_train = torchvision.datasets.HMDB51('video_data/', 'test_train_splits/', num_frames,frame_rate=5,
                                                step_between_clips = clip_steps, fold=1, train=True,
                                                transform=transform, num_workers=2)


hmdb51_test = torchvision.datasets.HMDB51('video_data/', 'test_train_splits/', num_frames,frame_rate=5,
                                                step_between_clips = clip_steps, fold=1, train=False,
                                                transform=transform_test, num_workers=2)
train_loader = DataLoader(hmdb51_train, batch_size=Bs_Train, shuffle=True)
test_loader  = DataLoader(hmdb51_test, batch_size=Bs_Test, shuffle=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-22252e81d0c6> in <module>
#       7 import torch
#       8 import transforms as T
# ----> 9 from movinets import MoViNet
#      10 from movinets.config import _C
#      11
#
# E:\MoViNet-pytorch-main\movinets\__init__.py in <module>
# ----> 1 from movinets.models import MoViNet
#
# E:\MoViNet-pytorch-main\movinets\models.py in <module>
#       9 import torch.nn.functional as F
#      10 from typing import Any, Callable, Optional, Tuple, Union
# ---> 11 from einops import rearrange
#      12 from torch import nn, Tensor
#      13
#
# ModuleNotFoundError: No module named 'einops'

# %%
def train_iter(model, optimz, data_load, loss_val):
    samples = len(data_load.dataset)
    model.train()
    model.cuda()
    model.clean_activation_buffers()
    optimz.zero_grad()
    for i, (data,_ , target) in enumerate(data_load):
        out = F.log_softmax(model(data.cuda()), dim=1)
        loss = F.nll_loss(out, target.cuda())
        loss.backward()
        optimz.step()
        optimz.zero_grad()
        model.clean_activation_buffers()
        if i % 50 == 0:
            print('[' +  '{:5}'.format(i * len(data)) + '/' + '{:5}'.format(samples) +
                  ' (' + '{:3.0f}'.format(100 * i / len(data_load)) + '%)]  Loss: ' +
                  '{:6.4f}'.format(loss.item()))
            loss_val.append(loss.item())

def evaluate(model, data_load, loss_val):
    model.eval()
    
    samples = len(data_load.dataset)
    csamp = 0
    tloss = 0
    model.clean_activation_buffers()
    with torch.no_grad():
        for data, _, target in data_load:
            output = F.log_softmax(model(data.cuda()), dim=1)
            loss = F.nll_loss(output, target.cuda(), reduction='sum')
            _, pred = torch.max(output, dim=1)
            
            tloss += loss.item()
            csamp += pred.eq(target.cuda()).sum()
            model.clean_activation_buffers()
    aloss = tloss / samples
    loss_val.append(aloss)
    print('\nAverage test loss: ' + '{:.4f}'.format(aloss) +
          '  Accuracy:' + '{:5}'.format(csamp) + '/' +
          '{:5}'.format(samples) + ' (' +
          '{:4.2f}'.format(100.0 * csamp / samples) + '%)\n')
    
def train_iter_stream(model, optimz, data_load, loss_val, n_clips = 2, n_clip_frames=8):
    """
    In causal mode with stream buffer a single video is fed to the network
    using subclips of lenght n_clip_frames. 
    n_clips*n_clip_frames should be equal to the total number of frames presents
    in the video.
    
    n_clips : number of clips that are used
    n_clip_frames : number of frame contained in each clip
    """
    #clean the buffer of activations
    samples = len(data_load.dataset)
    model.cuda()
    model.train()
    model.clean_activation_buffers()
    optimz.zero_grad()
    
    for i, (data,_, target) in enumerate(data_load):
        data = data.cuda()
        target = target.cuda()
        l_batch = 0
        #backward pass for each clip
        for j in range(n_clips):
            output = F.log_softmax(model(data[:,:,(n_clip_frames)*(j):(n_clip_frames)*(j+1)]), dim=1)
            loss = F.nll_loss(output, target)
            _, pred = torch.max(output, dim=1)
            loss = F.nll_loss(output, target)/n_clips
            loss.backward()
        l_batch += loss.item()*n_clips
        optimz.step()
        optimz.zero_grad()
        
        #clean the buffer of activations
        model.clean_activation_buffers()
        if i % 50 == 0:
            print('[' +  '{:5}'.format(i * len(data)) + '/' + '{:5}'.format(samples) +
                  ' (' + '{:3.0f}'.format(100 * i / len(data_load)) + '%)]  Loss: ' +
                  '{:6.4f}'.format(l_batch))
            loss_val.append(l_batch)

def evaluate_stream(model, data_load, loss_val, n_clips = 2, n_clip_frames=8):
    model.eval()
    model.cuda()
    samples = len(data_load.dataset)
    csamp = 0
    tloss = 0
    with torch.no_grad():
        for data, _, target in data_load:
            data = data.cuda()
            target = target.cuda()
            model.clean_activation_buffers()
            for j in range(n_clips):
                output = F.log_softmax(model(data[:,:,(n_clip_frames)*(j):(n_clip_frames)*(j+1)]), dim=1)
                loss = F.nll_loss(output, target)
            _, pred = torch.max(output, dim=1)
            tloss += loss.item()
            csamp += pred.eq(target).sum()

    aloss = tloss /  len(data_load)
    loss_val.append(aloss)
    print('\nAverage test loss: ' + '{:.4f}'.format(aloss) +
          '  Accuracy:' + '{:5}'.format(csamp) + '/' +
          '{:5}'.format(samples) + ' (' +
          '{:4.2f}'.format(100.0 * csamp / samples) + '%)\n')

# %%
N_EPOCHS = 1

model = MoViNet(_C.MODEL.MoViNetA0, causal = True, pretrained = True )
start_time = time.time()

trloss_val, tsloss_val = [], []
model.classifier[3] = torch.nn.Conv3d(2048, 51, (1,1,1))
optimz = optim.Adam(model.parameters(), lr=0.00005)
for epoch in range(1, N_EPOCHS + 1):
    print('Epoch:', epoch)
    train_iter_stream(model, optimz, train_loader, trloss_val)
    evaluate_stream(model, test_loader, tsloss_val)

print('Execution time:', '{:5.2f}'.format(time.time() - start_time), 'seconds')

# %%
N_EPOCHS = 1

model = MoViNet(_C.MODEL.MoViNetA0, causal = False, pretrained = True )
start_time = time.time()

trloss_val, tsloss_val = [], []
model.classifier[3] = torch.nn.Conv3d(2048, 51, (1,1,1))
optimz = optim.Adam(model.parameters(), lr=0.00005)
for epoch in range(1, N_EPOCHS + 1):
    print('Epoch:', epoch)
    train_iter(model, optimz, train_loader, trloss_val)
    evaluate(model, test_loader, tsloss_val)

print('Execution time:', '{:5.2f}'.format(time.time() - start_time), 'seconds')
